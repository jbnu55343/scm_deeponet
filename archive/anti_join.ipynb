# %%
import pandas as pd
orig = pd.read_csv("F:\git_local\scm_deeponet\solomon_dataset\C1\C101.csv")                # 原始点
snap = pd.read_csv('customers_snapped.csv')        # 已吸附点
unmatched = orig[~orig['CUST NO.'].isin(snap['id'])]     # 不在 snapped 的就是未吸附
unmatched.to_csv('customers_unmatched.csv', index=False)
